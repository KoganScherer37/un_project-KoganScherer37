# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
pd.read_csv('../data/gdp_percapita.csv')
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %%
internet_df = pd.read_csv('../data/internet_use.csv',nrows = 4487)
internet_df
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 0        Afghanistan  2014  6.390000              NaN
# 1        Afghanistan  2013  5.900000              NaN
# 2        Afghanistan  2012  5.454545              NaN
# 3        Afghanistan  2011  5.000000              NaN
# 4        Afghanistan  2010  4.000000              NaN
# ...              ...   ...       ...              ...
# 4482        Zimbabwe  2005  8.015978              NaN
# 4483        Zimbabwe  2004  6.564045              NaN
# 4484        Zimbabwe  2003  6.394786              NaN
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
#
# [4487 rows x 4 columns]

# %%
gdp_df.shape
# Out:
# (7176, 4)

# %% [markdown]
# 98.A (7176,4)

# %%
internet_df.shape
# Out:
# (4487, 4)

# %% [markdown]
# 98.B (4496, 4)

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7166        Zimbabwe  1999  2872.714795              NaN
# 7167        Zimbabwe  1998  2915.052992              NaN
# 7168        Zimbabwe  1997  2856.118188              NaN
# 7169        Zimbabwe  1996  2808.558556              NaN
# 7170        Zimbabwe  1995  2573.993785              NaN
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year      Value  Value Footnotes
# 4477        Zimbabwe  2010  11.500000              NaN
# 4478        Zimbabwe  2009  11.360000              NaN
# 4479        Zimbabwe  2008  11.400000              NaN
# 4480        Zimbabwe  2007  10.850000              NaN
# 4481        Zimbabwe  2006   9.791842              NaN
# 4482        Zimbabwe  2005   8.015978              NaN
# 4483        Zimbabwe  2004   6.564045              NaN
# 4484        Zimbabwe  2003   6.394786              NaN
# 4485        Zimbabwe  2002   3.994356              NaN
# 4486        Zimbabwe  2001   0.799846              NaN

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes'])
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %%
internet_df = internet_df.drop(columns = ['Value Footnotes'])
internet_df
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4482        Zimbabwe  2005  8.015978
# 4483        Zimbabwe  2004  6.564045
# 4484        Zimbabwe  2003  6.394786
# 4485        Zimbabwe  2002  3.994356
# 4486        Zimbabwe  2001  0.799846
#
# [4487 rows x 3 columns]

# %%
gdp_df = gdp_df.rename(columns = {"Country or Area": 'Country', "Value": "GDP_Per_Capita"})
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
internet_df = internet_df.rename(columns = {"Country or Area": "Country", "Value": "Internet_Users_Pct"})
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4482     Zimbabwe  2005            8.015978
# 4483     Zimbabwe  2004            6.564045
# 4484     Zimbabwe  2003            6.394786
# 4485     Zimbabwe  2002            3.994356
# 4486     Zimbabwe  2001            0.799846
#
# [4487 rows x 3 columns]

# %%
gdp_and_internet_use = gdp_df.merge(internet_df,on = "Country")
gdp_and_internet_use
# Out:
#             Country  Year_x  GDP_Per_Capita  Year_y  Internet_Users_Pct
# 0       Afghanistan    2020     1970.560169    2014            6.390000
# 1       Afghanistan    2020     1970.560169    2013            5.900000
# 2       Afghanistan    2020     1970.560169    2012            5.454545
# 3       Afghanistan    2020     1970.560169    2011            5.000000
# 4       Afghanistan    2020     1970.560169    2010            4.000000
# ...             ...     ...             ...     ...                 ...
# 108282     Zimbabwe    1990     2652.129209    2005            8.015978
# 108283     Zimbabwe    1990     2652.129209    2004            6.564045
# 108284     Zimbabwe    1990     2652.129209    2003            6.394786
# 108285     Zimbabwe    1990     2652.129209    2002            3.994356
# 108286     Zimbabwe    1990     2652.129209    2001            0.799846
#
# [108287 rows x 5 columns]

# %%
print(gdp_df)
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
print(internet_df)
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4482     Zimbabwe  2005            8.015978
# 4483     Zimbabwe  2004            6.564045
# 4484     Zimbabwe  2003            6.394786
# 4485     Zimbabwe  2002            3.994356
# 4486     Zimbabwe  2001            0.799846
#
# [4487 rows x 3 columns]

# %%
print(gdp_df.Country)
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 7171       Zimbabwe
# 7172       Zimbabwe
# 7173       Zimbabwe
# 7174       Zimbabwe
# 7175       Zimbabwe
# Name: Country, Length: 7176, dtype: object

# %%
print(gdp_df.Year)
# Out:
# 0       2020
# 1       2019
# 2       2018
# 3       2017
# 4       2016
#         ...
# 7171    1994
# 7172    1993
# 7173    1992
# 7174    1991
# 7175    1990
# Name: Year, Length: 7176, dtype: int64

# %%
print(internet_df.Year)
# Out:
# 0       2014
# 1       2013
# 2       2012
# 3       2011
# 4       2010
#         ...
# 4482    2005
# 4483    2004
# 4484    2003
# 4485    2002
# 4486    2001
# Name: Year, Length: 4487, dtype: int64

# %%
gdp_df.Year
# Out:
# 0       2020
# 1       2019
# 2       2018
# 3       2017
# 4       2016
#         ...
# 7171    1994
# 7172    1993
# 7173    1992
# 7174    1991
# 7175    1990
# Name: Year, Length: 7176, dtype: int64

# %%
gdp_df.dtypes
# Out:
# Country            object
# Year                int64
# GDP_Per_Capita    float64
# dtype: object

# %%
internet_df.dtypes
# Out:
# Country                object
# Year                    int64
# Internet_Users_Pct    float64
# dtype: object

# %%
gdp_df["Year"]= gdp_df.Year.astype(object)
gdp_df.dtypes
# Out:
# Country            object
# Year               object
# GDP_Per_Capita    float64
# dtype: object

# %%
gdp_and_internet_use = gdp_df.merge(internet_df,on = ["Country", "Year"], how = "outer")
gdp_and_internet_use
# Out:
# C:\Users\kogan\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)
#           Country    Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2020.0     1970.560169                 NaN
# 1     Afghanistan  2019.0     2065.036235                 NaN
# 2     Afghanistan  2018.0     2033.804389                 NaN
# 3     Afghanistan  2017.0     2058.400221                 NaN
# 4     Afghanistan  2016.0     2057.067978                 NaN
# ...           ...     ...             ...                 ...
# 8251        Yemen  1999.0             NaN            0.056629
# 8252        Yemen  1998.0             NaN            0.023323
# 8253        Yemen  1997.0             NaN            0.015025
# 8254        Yemen  1996.0             NaN            0.000621
# ...

# %%
gdp_and_internet_use.head()
# Out:
#        Country    Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2020.0     1970.560169                 NaN
# 1  Afghanistan  2019.0     2065.036235                 NaN
# 2  Afghanistan  2018.0     2033.804389                 NaN
# 3  Afghanistan  2017.0     2058.400221                 NaN
# 4  Afghanistan  2016.0     2057.067978                 NaN

# %%
gdp_and_internet_use.tail()
# Out:
#      Country    Year  GDP_Per_Capita  Internet_Users_Pct
# 8251   Yemen  1999.0             NaN            0.056629
# 8252   Yemen  1998.0             NaN            0.023323
# 8253   Yemen  1997.0             NaN            0.015025
# 8254   Yemen  1996.0             NaN            0.000621
# 8255   Yemen  1990.0             NaN            0.000000

# %%
year_list = [2004, 2009, 2014]
select_years = gdp_and_internet_use.query("Year in @year_list")
select_years
# Out:
#                           Country    Year  GDP_Per_Capita  Internet_Users_Pct
# 6                     Afghanistan  2014.0     2102.384604            6.390000
# 11                    Afghanistan  2009.0     1758.904477            3.550000
# 16                    Afghanistan  2004.0     1200.278013            0.105809
# 25    Africa Eastern and Southern  2014.0     3677.319414                 NaN
# 30    Africa Eastern and Southern  2009.0     3461.681409                 NaN
# ...                           ...     ...             ...                 ...
# 8219        Virgin Islands (U.S.)  2009.0             NaN           27.396510
# 8224        Virgin Islands (U.S.)  2004.0             NaN           27.377009
# 8236                        Yemen  2014.0             NaN           22.550000
# 8241                        Yemen  2009.0             NaN            9.960000
# 8246                        Yemen  2004.0             NaN            0.881223
#
# [841 rows x 4 columns]

# %%
gdp_and_internet_use.dtypes
# Out:
# Country                object
# Year                   object
# GDP_Per_Capita        float64
# Internet_Users_Pct    float64
# dtype: object

# %%
gdp_and_internet_use['Year'] = gdp_and_internet_use.Year.astype('int64')
gdp_and_internet_use.dtypes
# Out:
# Country                object
# Year                    int64
# GDP_Per_Capita        float64
# Internet_Users_Pct    float64
# dtype: object

# %%
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2020     1970.560169                 NaN
# 1     Afghanistan  2019     2065.036235                 NaN
# 2     Afghanistan  2018     2033.804389                 NaN
# 3     Afghanistan  2017     2058.400221                 NaN
# 4     Afghanistan  2016     2057.067978                 NaN
# ...           ...   ...             ...                 ...
# 8251        Yemen  1999             NaN            0.056629
# 8252        Yemen  1998             NaN            0.023323
# 8253        Yemen  1997             NaN            0.015025
# 8254        Yemen  1996             NaN            0.000621
# 8255        Yemen  1990             NaN            0.000000
#
# [8256 rows x 4 columns]

# %%
select_years['Year'] = select_years.Year.astype('int64')
select_years.dtypes
# Out:
# C:\Users\kogan\AppData\Local\Temp\ipykernel_24420\1844908707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   select_years['Year'] = select_years.Year.astype('int64')
# Country                object
# Year                    int64
# GDP_Per_Capita        float64
# Internet_Users_Pct    float64
# dtype: object

# %%
select_years
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6                     Afghanistan  2014     2102.384604            6.390000
# 11                    Afghanistan  2009     1758.904477            3.550000
# 16                    Afghanistan  2004     1200.278013            0.105809
# 25    Africa Eastern and Southern  2014     3677.319414                 NaN
# 30    Africa Eastern and Southern  2009     3461.681409                 NaN
# ...                           ...   ...             ...                 ...
# 8219        Virgin Islands (U.S.)  2009             NaN           27.396510
# 8224        Virgin Islands (U.S.)  2004             NaN           27.377009
# 8236                        Yemen  2014             NaN           22.550000
# 8241                        Yemen  2009             NaN            9.960000
# 8246                        Yemen  2004             NaN            0.881223
#
# [841 rows x 4 columns]

# %%
gdp_net_2004 = select_years.loc[select_years['Year'] == 2004]
gdp_net_2004
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 16                    Afghanistan  2004     1200.278013            0.105809
# 35    Africa Eastern and Southern  2004     3093.224738                 NaN
# 66     Africa Western and Central  2004     3165.091102                 NaN
# 97                        Albania  2004     7580.138864            2.420388
# 128                       Algeria  2004    10058.426227            4.634475
# ...                           ...   ...             ...                 ...
# 8157                       Turkey  2004             NaN           14.580000
# 8180                    Venezuela  2004             NaN            8.404470
# 8204                     Viet Nam  2004             NaN            7.642409
# 8224        Virgin Islands (U.S.)  2004             NaN           27.377009
# 8246                        Yemen  2004             NaN            0.881223
#
# [279 rows x 4 columns]

# %%
gdp_net_2004 = gdp_net_2004.reset_index(drop = True)
gdp_net_2004
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0                    Afghanistan  2004     1200.278013            0.105809
# 1    Africa Eastern and Southern  2004     3093.224738                 NaN
# 2     Africa Western and Central  2004     3165.091102                 NaN
# 3                        Albania  2004     7580.138864            2.420388
# 4                        Algeria  2004    10058.426227            4.634475
# ..                           ...   ...             ...                 ...
# 274                       Turkey  2004             NaN           14.580000
# 275                    Venezuela  2004             NaN            8.404470
# 276                     Viet Nam  2004             NaN            7.642409
# 277        Virgin Islands (U.S.)  2004             NaN           27.377009
# 278                        Yemen  2004             NaN            0.881223
#
# [279 rows x 4 columns]

# %%
type(gdp_net_2004)
# Out:
# pandas.core.frame.DataFrame

# %%
gdp_net_2009 = select_years.loc[select_years['Year'] == 2009]
gdp_net_2009
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 11                    Afghanistan  2009     1758.904477             3.55000
# 30    Africa Eastern and Southern  2009     3461.681409                 NaN
# 61     Africa Western and Central  2009     3652.114030                 NaN
# 92                        Albania  2009    10313.916338            41.20000
# 123                       Algeria  2009    10782.347384            11.23000
# ...                           ...   ...             ...                 ...
# 8152                       Turkey  2009             NaN            36.40000
# 8175                    Venezuela  2009             NaN            32.70000
# 8199                     Viet Nam  2009             NaN            26.55000
# 8219        Virgin Islands (U.S.)  2009             NaN            27.39651
# 8241                        Yemen  2009             NaN             9.96000
#
# [281 rows x 4 columns]

# %%
gdp_net_2014 = select_years.loc[select_years['Year'] == 2014]
gdp_net_2014
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6                     Afghanistan  2014     2102.384604                6.39
# 25    Africa Eastern and Southern  2014     3677.319414                 NaN
# 56     Africa Western and Central  2014     4215.646000                 NaN
# 87                        Albania  2014    11586.833878               60.10
# 118                       Algeria  2014    11512.690472               18.09
# ...                           ...   ...             ...                 ...
# 8147                       Turkey  2014             NaN               51.04
# 8170                    Venezuela  2014             NaN               57.00
# 8194                     Viet Nam  2014             NaN               48.31
# 8214        Virgin Islands (U.S.)  2014             NaN               50.07
# 8236                        Yemen  2014             NaN               22.55
#
# [281 rows x 4 columns]

# %%
gdp_net_2009 = gdp_net_2009.reset_index(drop = True)
gdp_net_2009
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0                    Afghanistan  2009     1758.904477             3.55000
# 1    Africa Eastern and Southern  2009     3461.681409                 NaN
# 2     Africa Western and Central  2009     3652.114030                 NaN
# 3                        Albania  2009    10313.916338            41.20000
# 4                        Algeria  2009    10782.347384            11.23000
# ..                           ...   ...             ...                 ...
# 276                       Turkey  2009             NaN            36.40000
# 277                    Venezuela  2009             NaN            32.70000
# 278                     Viet Nam  2009             NaN            26.55000
# 279        Virgin Islands (U.S.)  2009             NaN            27.39651
# 280                        Yemen  2009             NaN             9.96000
#
# [281 rows x 4 columns]

# %%
gdp_net_2014 = gdp_net_2014.reset_index(drop = True)
gdp_net_2014
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0                    Afghanistan  2014     2102.384604                6.39
# 1    Africa Eastern and Southern  2014     3677.319414                 NaN
# 2     Africa Western and Central  2014     4215.646000                 NaN
# 3                        Albania  2014    11586.833878               60.10
# 4                        Algeria  2014    11512.690472               18.09
# ..                           ...   ...             ...                 ...
# 276                       Turkey  2014             NaN               51.04
# 277                    Venezuela  2014             NaN               57.00
# 278                     Viet Nam  2014             NaN               48.31
# 279        Virgin Islands (U.S.)  2014             NaN               50.07
# 280                        Yemen  2014             NaN               22.55
#
# [281 rows x 4 columns]

# %%
top_net_user_2014 = gdp_net_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
top_net_user_2014
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 93               Iceland  2014    50450.741612               98.16
# 21               Bermuda  2014    77361.104881               96.80
# 163               Norway  2014    62390.130313               96.30
# 52               Denmark  2014    52048.335493               95.99
# 242              Andorra  2014             NaN               95.90
# ..                   ...   ...             ...                 ...
# 227               Tuvalu  2014     3497.520822                 NaN
# 233  Upper middle income  2014    14564.823543                 NaN
# 237              Vietnam  2014     7601.858491                 NaN
# 238   West Bank and Gaza  2014     5967.073437                 NaN
# 239                World  2014    15224.439424                 NaN
#
# [281 rows x 4 columns]

# %% [markdown]
# Iceland, 98.16%

# %%
btm_net_user_2014 = gdp_net_2014.sort_values(by = 'Internet_Users_Pct', ascending = True)
btm_net_user_2014
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 250  Dem. People's Rep. of Korea  2014             NaN                0.00
# 252                      Eritrea  2014             NaN                0.99
# 220                  Timor-Leste  2014     3266.731666                1.14
# 30                       Burundi  2014      886.235296                1.38
# 198                      Somalia  2014      917.876549                1.63
# ..                           ...   ...             ...                 ...
# 227                       Tuvalu  2014     3497.520822                 NaN
# 233          Upper middle income  2014    14564.823543                 NaN
# 237                      Vietnam  2014     7601.858491                 NaN
# 238           West Bank and Gaza  2014     5967.073437                 NaN
# 239                        World  2014    15224.439424                 NaN
#
# [281 rows x 4 columns]

# %% [markdown]
# Dem. People's Rep. of Korea 0.00%

# %%
top_net_user_2004 = gdp_net_2004.sort_values(by = 'Internet_Users_Pct', ascending = False)
top_net_user_2004
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 207               Sweden  2004    44354.391062               83.89
# 91               Iceland  2004    46051.743888               83.88
# 51               Denmark  2004    50446.541605               80.93
# 160               Norway  2004    60699.566582               77.69
# 258      Korea (Rep. of)  2004             NaN               72.70
# ..                   ...   ...             ...                 ...
# 221               Tuvalu  2004     3482.986203                 NaN
# 227  Upper middle income  2004     8586.760074                 NaN
# 231              Vietnam  2004     4556.618333                 NaN
# 232   West Bank and Gaza  2004     4485.525458                 NaN
# 233                World  2004    12130.596221                 NaN
#
# [279 rows x 4 columns]

# %% [markdown]
# Sweden 83.89%

# %%
btm_net_user_2004 = gdp_net_2004.sort_values(by = 'Internet_Users_Pct', ascending = True)
btm_net_user_2004
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 244  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 149                      Myanmar  2004     1473.020996            0.024337
# 121                      Liberia  2004     1219.414000            0.031011
# 210                   Tajikistan  2004     1837.331120            0.077480
# 0                    Afghanistan  2004     1200.278013            0.105809
# ..                           ...   ...             ...                 ...
# 221                       Tuvalu  2004     3482.986203                 NaN
# 227          Upper middle income  2004     8586.760074                 NaN
# 231                      Vietnam  2004     4556.618333                 NaN
# 232           West Bank and Gaza  2004     4485.525458                 NaN
# 233                        World  2004    12130.596221                 NaN
#
# [279 rows x 4 columns]

# %% [markdown]
# Dem. People's Rep. of Korea 0.00%

# %%
top_net_user_2009 = gdp_net_2009.sort_values(by = 'Internet_Users_Pct', ascending = False)
top_net_user_2009
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 92               Iceland  2009    48770.950337               93.00
# 162               Norway  2009    61689.558543               92.08
# 210               Sweden  2009    45492.768175               91.00
# 155          Netherlands  2009    51607.605727               89.63
# 129           Luxembourg  2009   112230.081410               87.31
# ..                   ...   ...             ...                 ...
# 217           The Gambia  2009     2283.186180                 NaN
# 230  Upper middle income  2009    11352.407014                 NaN
# 234              Vietnam  2009     5965.163211                 NaN
# 235   West Bank and Gaza  2009     5250.116075                 NaN
# 236                World  2009    13450.307511                 NaN
#
# [281 rows x 4 columns]

# %% [markdown]
# Iceland 93%

# %%
btm_net_user_2009 = gdp_net_2009.sort_values(by = 'Internet_Users_Pct', ascending = True)
btm_net_user_2009
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 247  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 218                  Timor-Leste  2009     2729.281474            0.185252
# 151                      Myanmar  2009     2527.390561            0.220000
# 190                 Sierra Leone  2009     1365.218902            0.260000
# 33                      Cambodia  2009     2603.583593            0.530000
# ..                           ...   ...             ...                 ...
# 217                   The Gambia  2009     2283.186180                 NaN
# 230          Upper middle income  2009    11352.407014                 NaN
# 234                      Vietnam  2009     5965.163211                 NaN
# 235           West Bank and Gaza  2009     5250.116075                 NaN
# 236                        World  2009    13450.307511                 NaN
#
# [281 rows x 4 columns]

# %% [markdown]
# Dem. People's Rep. of Korea 0.00%

# %%
top_gdp_2014 = gdp_net_2014.sort_values(by = 'GDP_Per_Capita', ascending = False)
top_gdp_2014
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 131       Macao SAR, China  2014   155201.740571                 NaN
# 130             Luxembourg  2014   113313.578898               94.67
# 180                  Qatar  2014    95578.261511               91.49
# 192              Singapore  2014    87616.637527               82.00
# 21                 Bermuda  2014    77361.104881               96.80
# ..                     ...   ...             ...                 ...
# 276                 Turkey  2014             NaN               51.04
# 277              Venezuela  2014             NaN               57.00
# 278               Viet Nam  2014             NaN               48.31
# 279  Virgin Islands (U.S.)  2014             NaN               50.07
# 280                  Yemen  2014             NaN               22.55
#
# [281 rows x 4 columns]

# %% [markdown]
# Macao SAR, China 155201.74

# %%
btm_gdp_2014 = gdp_net_2014.sort_values(by = 'GDP_Per_Capita', ascending = True)
btm_gdp_2014
# Out:
#                       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 38   Central African Republic  2014      822.611195                 NaN
# 30                    Burundi  2014      886.235296                1.38
# 198                   Somalia  2014      917.876549                1.63
# 51            Dem. Rep. Congo  2014     1029.790813                 NaN
# 159                     Niger  2014     1126.805440                1.95
# ..                        ...   ...             ...                 ...
# 276                    Turkey  2014             NaN               51.04
# 277                 Venezuela  2014             NaN               57.00
# 278                  Viet Nam  2014             NaN               48.31
# 279     Virgin Islands (U.S.)  2014             NaN               50.07
# 280                     Yemen  2014             NaN               22.55
#
# [281 rows x 4 columns]

# %% [markdown]
# Central African Republic 822.611

# %%
top_gdp_2004 = gdp_net_2004.sort_values(by = 'GDP_Per_Capita', ascending = False)
top_gdp_2004
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 127             Luxembourg  2004   107634.837198           65.880000
# 224   United Arab Emirates  2004    97757.855152           30.131296
# 177                  Qatar  2004    93748.550125           20.701648
# 21                 Bermuda  2004    90195.811565           60.990867
# 183             San Marino  2004    80883.703264           50.566343
# ..                     ...   ...             ...                 ...
# 274                 Turkey  2004             NaN           14.580000
# 275              Venezuela  2004             NaN            8.404470
# 276               Viet Nam  2004             NaN            7.642409
# 277  Virgin Islands (U.S.)  2004             NaN           27.377009
# 278                  Yemen  2004             NaN            0.881223
#
# [279 rows x 4 columns]

# %% [markdown]
# Luxembourg 107634.837

# %%
btm_gdp_2004 = gdp_net_2004.sort_values(by = 'GDP_Per_Capita', ascending = True)
btm_gdp_2004
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 50         Dem. Rep. Congo  2004      757.686099                 NaN
# 148             Mozambique  2004      792.727274            0.679448
# 64                Ethiopia  2004      793.093753            0.155335
# 30                 Burundi  2004      817.461177            0.349060
# 156                  Niger  2004      929.217222            0.189934
# ..                     ...   ...             ...                 ...
# 274                 Turkey  2004             NaN           14.580000
# 275              Venezuela  2004             NaN            8.404470
# 276               Viet Nam  2004             NaN            7.642409
# 277  Virgin Islands (U.S.)  2004             NaN           27.377009
# 278                  Yemen  2004             NaN            0.881223
#
# [279 rows x 4 columns]

# %% [markdown]
# Dem. Rep. Congo 757.686

# %%
top_gdp_2009 = gdp_net_2009.sort_values(by = 'GDP_Per_Capita', ascending = False)
top_gdp_2009
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 129             Luxembourg  2009   112230.081410            87.31000
# 130       Macao SAR, China  2009    96493.793065                 NaN
# 21                 Bermuda  2009    89961.982744            83.25000
# 179                  Qatar  2009    89954.846115            53.10000
# 185             San Marino  2009    77188.629829            54.21000
# ..                     ...   ...             ...                 ...
# 276                 Turkey  2009             NaN            36.40000
# 277              Venezuela  2009             NaN            32.70000
# 278               Viet Nam  2009             NaN            26.55000
# 279  Virgin Islands (U.S.)  2009             NaN            27.39651
# 280                  Yemen  2009             NaN             9.96000
#
# [281 rows x 4 columns]

# %% [markdown]
# Luxembourg 112230.081

# %%
btm_gdp_2009 = gdp_net_2009.sort_values(by = 'GDP_Per_Capita', ascending = True)
btm_gdp_2009
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 30                 Burundi  2009      831.564843             0.90000
# 51         Dem. Rep. Congo  2009      835.611723                 NaN
# 150             Mozambique  2009      991.322835             2.68000
# 158                  Niger  2009      991.698425             0.76000
# 65                Ethiopia  2009     1150.206044             0.54000
# ..                     ...   ...             ...                 ...
# 276                 Turkey  2009             NaN            36.40000
# 277              Venezuela  2009             NaN            32.70000
# 278               Viet Nam  2009             NaN            26.55000
# 279  Virgin Islands (U.S.)  2009             NaN            27.39651
# 280                  Yemen  2009             NaN             9.96000
#
# [281 rows x 4 columns]

# %% [markdown]
# Burundi 831.564

# %%
scat_plt_2004 = plt.scatter(x = 'GDP_Per_Capita', y = 'Internet_Users_Pct', data = gdp_net_2004, color = 'green', marker = 'd')
plt.xlabel('GDP')
plt.ylabel('Net use')
# Out:
# Text(0, 0.5, 'Net use')

# %%
scat_plt_2009 = plt.scatter(x = 'GDP_Per_Capita', y = 'Internet_Users_Pct', data = gdp_net_2009, color = 'purple', marker = 'p')
plt.xlabel('GDP')
plt.ylabel('Net use')
# Out:
# Text(0, 0.5, 'Net use')

# %%
scat_plt_2014 = plt.scatter(x = 'GDP_Per_Capita', y = 'Internet_Users_Pct', data = gdp_net_2014, color = 'red', marker = '+')
plt.xlabel('GDP')
plt.ylabel('Net use')
# Out:
# Text(0, 0.5, 'Net use')

# %% [markdown]
# Is seems that through the years, as internet use grows, so does GDP. Likely due to the growth in popularity of cell phones and more accessible internet.

# %%
hist_gdp_2014 = gdp_net_2014['GDP_Per_Capita'].hist(color = 'orange')

hist_gdp_2014.set(xlabel = 'GDP per capita', ylabel = 'Frequency')
# Out:
# [Text(0.5, 0, 'GDP per capita'), Text(0, 0.5, 'Frequency')]

# %%
hist_net_2014 = gdp_net_2014['Internet_Users_Pct'].hist(color = 'teal')

hist_net_2014.set(xlabel = 'Internet Users', ylabel = 'Frequency')
# Out:
# [Text(0.5, 0, 'Internet Users'), Text(0, 0.5, 'Frequency')]

# %%
hist_gdp_2004 = gdp_net_2004['GDP_Per_Capita'].hist(color = 'orange')

hist_gdp_2004.set(xlabel = 'GDP per capita', ylabel = 'Frequency')
# Out:
# [Text(0.5, 0, 'GDP per capita'), Text(0, 0.5, 'Frequency')]

# %%
hist_net_2004 = gdp_net_2004['Internet_Users_Pct'].hist(color = 'teal')

hist_net_2004.set(xlabel = 'Internet Users', ylabel = 'Frequency')
# Out:
# [Text(0.5, 0, 'Internet Users'), Text(0, 0.5, 'Frequency')]

# %%
hist_gdp_2009 = gdp_net_2009['GDP_Per_Capita'].hist(color = 'orange')

hist_gdp_2009.set(xlabel = 'GDP per capita', ylabel = 'Frequency')
# Out:
# [Text(0.5, 0, 'GDP per capita'), Text(0, 0.5, 'Frequency')]

# %%
hist_net_2009 = gdp_net_2009['Internet_Users_Pct'].hist(color = 'teal')

hist_net_2009.set(xlabel = 'Internet Users', ylabel = 'Frequency')
# Out:
# [Text(0.5, 0, 'Internet Users'), Text(0, 0.5, 'Frequency')]

# %%
top5_net_user_2014 = gdp_net_2014.sort_values(by = 'Internet_Users_Pct', ascending = False).head()
top5_net_user_2014
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 93   Iceland  2014    50450.741612               98.16
# 21   Bermuda  2014    77361.104881               96.80
# 163   Norway  2014    62390.130313               96.30
# 52   Denmark  2014    52048.335493               95.99
# 242  Andorra  2014             NaN               95.90

# %%
type(top5_net_user_2014)
# Out:
# pandas.core.frame.DataFrame

# %%
top_5_net_countries = ['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra']
top_5_internet = select_years.query('Country in @top_5_net_countries')
top_5_internet
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 645   Bermuda  2014    77361.104881           96.800000
# 650   Bermuda  2009    89961.982744           83.250000
# 655   Bermuda  2004    90195.811565           60.990867
# 1561  Denmark  2014    52048.335493           95.990000
# 1566  Denmark  2009    50114.050052           86.840000
# 1571  Denmark  2004    50446.541605           80.930000
# 2803  Iceland  2014    50450.741612           98.160000
# 2808  Iceland  2009    48770.950337           93.000000
# 2813  Iceland  2004    46051.743888           83.880000
# 4880   Norway  2014    62390.130313           96.300000
# 4885   Norway  2009    61689.558543           92.080000
# 4890   Norway  2004    60699.566582           77.690000
# 7179  Andorra  2014             NaN           95.900000
# 7184  Andorra  2009             NaN           78.530000
# 7189  Andorra  2004             NaN           26.837954

# %%
top_5_internet.shape
# Out:
# (15, 4)

# %%
sns.set_style('ticks')

# %%
net_fgrid = sns.FacetGrid(top_5_internet, col = 'Country')
net_fgrid.map_dataframe(sns.scatterplot, x= 'Year', y = 'Internet_Users_Pct', marker = '*', s= 300, color = 'indigo')
net_fgrid.set_axis_labels('Year', 'Internet Use %')
net_fgrid.set_titles(col_template = '{col_name}')
net_fgrid.set(xticks = [2004,2009,2014]);

# %% [markdown]
# Bermuda had the greatest growth.

# %%
btm5_net_user_2014 = gdp_net_2014.sort_values(by = 'Internet_Users_Pct', ascending = True).head()
btm5_net_user_2014
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 250  Dem. People's Rep. of Korea  2014             NaN                0.00
# 252                      Eritrea  2014             NaN                0.99
# 220                  Timor-Leste  2014     3266.731666                1.14
# 30                       Burundi  2014      886.235296                1.38
# 198                      Somalia  2014      917.876549                1.63

# %%
btm_5_net_countries = ["Dem. People's Rep. of Korea",'Eritrea','Timor-Leste', 'Burundi', 'Somalia', ]
btm_5_internet = select_years.query('Country in @btm_5_net_countries')
btm_5_internet
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 920                       Burundi  2014      886.235296            1.380000
# 925                       Burundi  2009      831.564843            0.900000
# 930                       Burundi  2004      817.461177            0.349060
# 5877                      Somalia  2014      917.876549            1.630000
# 6536                  Timor-Leste  2014     3266.731666            1.140000
# 6541                  Timor-Leste  2009     2729.281474            0.185252
# 6546                  Timor-Leste  2004     2258.384170                 NaN
# 7394  Dem. People's Rep. of Korea  2014             NaN            0.000000
# 7398  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 7403  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 7452                      Eritrea  2014             NaN            0.990000
# ...

# %%
btm_5_internet.shape
# Out:
# (14, 4)

# %%
net_fgrid = sns.FacetGrid(btm_5_internet, col = 'Country')
net_fgrid.map_dataframe(sns.scatterplot, x= 'Year', y = 'Internet_Users_Pct', marker = '2', s= 300, color = 'orange')
net_fgrid.set_axis_labels('Year', 'Internet Use %')
net_fgrid.set_titles(col_template = '{col_name}')
net_fgrid.set(xticks = [2004,2009,2014]);

# %% [markdown]
# Dem. People's Rep. of Korea is consistently at 0%.

# %%
top5_gdp_2014 = gdp_net_2014.sort_values(by = 'GDP_Per_Capita', ascending = False).head()
top5_gdp_2014
# Out:
#               Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 131  Macao SAR, China  2014   155201.740571                 NaN
# 130        Luxembourg  2014   113313.578898               94.67
# 180             Qatar  2014    95578.261511               91.49
# 192         Singapore  2014    87616.637527               82.00
# 21            Bermuda  2014    77361.104881               96.80

# %%
top_5_gdp_countries = ['Macao SAR, China', 'Luxembourg','Qatar', 'Singapore', 'Bermuda']
top_5_gdp = select_years.query('Country in @top_5_gdp_countries')
top_5_gdp
# Out:
#                Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 645            Bermuda  2014    77361.104881           96.800000
# 650            Bermuda  2009    89961.982744           83.250000
# 655            Bermuda  2004    90195.811565           60.990867
# 3888        Luxembourg  2014   113313.578898           94.670000
# 3893        Luxembourg  2009   112230.081410           87.310000
# 3898        Luxembourg  2004   107634.837198           65.880000
# 3919  Macao SAR, China  2014   155201.740571                 NaN
# 3924  Macao SAR, China  2009    96493.793065                 NaN
# 3929  Macao SAR, China  2004    73322.928480                 NaN
# 5387             Qatar  2014    95578.261511           91.490000
# 5392             Qatar  2009    89954.846115           53.100000
# 5397             Qatar  2004    93748.550125           20.701648
# 5726         Singapore  2014    87616.637527           82.000000
# ...

# %%
net_fgrid = sns.FacetGrid(top_5_gdp, col = 'Country')
net_fgrid.map_dataframe(sns.scatterplot, x= 'Year', y = 'GDP_Per_Capita', marker = '^', s= 300, color = 'aqua')
net_fgrid.set_axis_labels('Year', 'Internet Use %')
net_fgrid.set_titles(col_template = '{col_name}')
net_fgrid.set(xticks = [2004,2009,2014]);

# %%
btm5_gdp_2014 = gdp_net_2014.sort_values(by = 'GDP_Per_Capita', ascending = True).head()
btm5_gdp_2014
# Out:
#                       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 38   Central African Republic  2014      822.611195                 NaN
# 30                    Burundi  2014      886.235296                1.38
# 198                   Somalia  2014      917.876549                1.63
# 51            Dem. Rep. Congo  2014     1029.790813                 NaN
# 159                     Niger  2014     1126.805440                1.95

# %%
btm_5_gdp_countries = ['Central African Republic', 'Burundi','Somalia', 'Dem. Rep. Congo', 'Niger']
btm_5_gdp = select_years.query('Country in @btm_5_gdp_countries')
btm_5_gdp
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 920                    Burundi  2014      886.235296            1.380000
# 925                    Burundi  2009      831.564843            0.900000
# 930                    Burundi  2004      817.461177            0.349060
# 1142  Central African Republic  2014      822.611195                 NaN
# 1147  Central African Republic  2009     1161.190011                 NaN
# 1152  Central African Republic  2004     1037.844670                 NaN
# 1530           Dem. Rep. Congo  2014     1029.790813                 NaN
# 1535           Dem. Rep. Congo  2009      835.611723                 NaN
# 1540           Dem. Rep. Congo  2004      757.686099                 NaN
# 4756                     Niger  2014     1126.805440            1.950000
# 4761                     Niger  2009      991.698425            0.760000
# 4766                     Niger  2004      929.217222            0.189934
# ...

# %%
net_fgrid = sns.FacetGrid(btm_5_gdp, col = 'Country')
net_fgrid.map_dataframe(sns.scatterplot, x= 'Year', y = 'GDP_Per_Capita', marker = '3', s= 300, color = 'red')
net_fgrid.set_axis_labels('Year', 'Internet Use %')
net_fgrid.set_titles(col_template = '{col_name}')
net_fgrid.set(xticks = [2004,2009,2014]);

# %% [markdown]
# The GDP in Central African Republic dived in 2014 after a coup brought upon the government in 2013 know as the Central African Republic conflict, resulting in a dip of the growth rate of up to 32% due to displaced refuges.

# %%
homicides_df = pd.read_csv('../data/in_homicides.csv', header = [1], index_col = 0, nrows = 202)

# %%
homicides_df= homicides_df.reset_index()
homicides_df
# Out:
#        Region                        Subregion  \
# 0        Asia                    Southern Asia
# 1      Europe                  Southern Europe
# 2      Africa                  Northern Africa
# 3     Oceania                        Polynesia
# 4      Europe                  Southern Europe
# ..        ...                              ...
# 197  Americas  Latin America and the Caribbean
# 198      Asia               South-eastern Asia
# 199      Asia                     Western Asia
# 200    Africa               Sub-Saharan Africa
# 201    Africa               Sub-Saharan Africa
#
#                                 country  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                        American Samoa
# 4                               Andorra
# ..                                  ...
# 197  Venezuela (Bolivarian Republic of)
# 198                            Viet Nam
# ...

# %%
homicides_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 46 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Region     202 non-null    object
#  1   Subregion  202 non-null    object
#  2   country    202 non-null    object
#  3   Source     202 non-null    object
#  4   2000       123 non-null    float64
#  5   2001       134 non-null    float64
#  6   2002       135 non-null    float64
#  7   2003       116 non-null    float64
#  8   2004       135 non-null    float64
#  9   2005       131 non-null    float64
#  10  2006       140 non-null    float64
#  11  2007       152 non-null    float64
#  12  2008       162 non-null    float64
#  13  2009       161 non-null    float64
#  14  2010       159 non-null    float64
#  15  2011       148 non-null    float64
#  16  2012       151 non-null    float64
#  17  2013       131 non-null    float64
#  18  2014       125 non-null    float64
# ...

# %%
homicides_df = pd.melt(homicides_df, id_vars = ['Region', 'Subregion', 'country', 'Source','2000', '2001','2002', '2003', '2004','2005','2006','2007','2008','2009','2010', '2011','2012', '2013', '2014','2015','2016','2017','2018','2019','2020'], var_name = 'Year2', value_name = 'Homicide Rate')
homicides_df
# Out:
#         Region                        Subregion  \
# 0         Asia                    Southern Asia
# 1       Europe                  Southern Europe
# 2       Africa                  Northern Africa
# 3      Oceania                        Polynesia
# 4       Europe                  Southern Europe
# ...        ...                              ...
# 4237  Americas  Latin America and the Caribbean
# 4238      Asia               South-eastern Asia
# 4239      Asia                     Western Asia
# 4240    Africa               Sub-Saharan Africa
# 4241    Africa               Sub-Saharan Africa
#
#                                  country  \
# 0                            Afghanistan
# 1                                Albania
# 2                                Algeria
# 3                         American Samoa
# 4                                Andorra
# ...                                  ...
# 4237  Venezuela (Bolivarian Republic of)
# 4238                            Viet Nam
# ...

# %%
homicides_df = pd.melt(homicides_df, id_vars = ['Region', 'Subregion', 'country', 'Source','Year2','Homicide Rate'], var_name = 'Year', value_name = 'Homicide Count')
homicides_df
# Out:
#          Region                        Subregion  \
# 0          Asia                    Southern Asia
# 1        Europe                  Southern Europe
# 2        Africa                  Northern Africa
# 3       Oceania                        Polynesia
# 4        Europe                  Southern Europe
# ...         ...                              ...
# 89077  Americas  Latin America and the Caribbean
# 89078      Asia               South-eastern Asia
# 89079      Asia                     Western Asia
# 89080    Africa               Sub-Saharan Africa
# 89081    Africa               Sub-Saharan Africa
#
#                                   country  \
# 0                             Afghanistan
# 1                                 Albania
# 2                                 Algeria
# 3                          American Samoa
# 4                                 Andorra
# ...                                   ...
# 89077  Venezuela (Bolivarian Republic of)
# ...

# %%
homicides_df = homicides_df[['country', 'Year', 'Homicide Count', 'Homicide Rate']]
homicides_df
# Out:
#                                   country  Year  Homicide Count  Homicide Rate
# 0                             Afghanistan  2000             NaN            NaN
# 1                                 Albania  2000           131.0           4.19
# 2                                 Algeria  2000             NaN            NaN
# 3                          American Samoa  2000             NaN            NaN
# 4                                 Andorra  2000             NaN            NaN
# ...                                   ...   ...             ...            ...
# 89077  Venezuela (Bolivarian Republic of)  2020             NaN            NaN
# 89078                            Viet Nam  2020             NaN            NaN
# 89079                               Yemen  2020             NaN            NaN
# 89080                              Zambia  2020             NaN            NaN
# 89081                            Zimbabwe  2020             NaN            NaN
#
# ...

# %%
homicides_df = homicides_df.rename(columns = {'country' : 'Country'})
homicides_df
# Out:
#                                   Country  Year  Homicide Count  Homicide Rate
# 0                             Afghanistan  2000             NaN            NaN
# 1                                 Albania  2000           131.0           4.19
# 2                                 Algeria  2000             NaN            NaN
# 3                          American Samoa  2000             NaN            NaN
# 4                                 Andorra  2000             NaN            NaN
# ...                                   ...   ...             ...            ...
# 89077  Venezuela (Bolivarian Republic of)  2020             NaN            NaN
# 89078                            Viet Nam  2020             NaN            NaN
# 89079                               Yemen  2020             NaN            NaN
# 89080                              Zambia  2020             NaN            NaN
# 89081                            Zimbabwe  2020             NaN            NaN
#
# ...
